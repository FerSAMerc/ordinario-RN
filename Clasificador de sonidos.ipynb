# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\fernando\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: numba>=0.43.0 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (0.54.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (1.7.1)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (0.24.2)
# Requirement already satisfied: audioread>=2.0.0 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (2.1.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (21.0)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (5.1.0)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: pooch>=1.0 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (1.5.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (1.20.3)
# Requirement already satisfied: joblib>=0.14 in c:\users\fernando\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\fernando\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (0.37.0)
# Requirement already satisfied: setuptools in c:\users\fernando\anaconda3\lib\site-packages (from numba>=0.43.0->librosa) (58.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\fernando\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (3.0.4)
# Requirement already satisfied: requests in c:\users\fernando\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.26.0)
# Requirement already satisfied: appdirs in c:\users\fernando\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: six>=1.3 in c:\users\fernando\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\fernando\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\fernando\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\fernando\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fernando\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\fernando\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\fernando\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fernando\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa) (2021.10.8)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename='Dataset/perro.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# !dir
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 4602-A5D7
#
#  Directorio de C:\Users\FERNANDO\Desktop\Redes
#
# 06/12/2021  02:40 p. m.    <DIR>          .
# 06/12/2021  02:40 p. m.    <DIR>          ..
# 06/12/2021  01:12 p. m.    <DIR>          .ipynb_checkpoints
# 06/12/2021  02:40 p. m.         1,992,856 Clasificador de sonidos.ipynb
# 06/12/2021  02:05 p. m.    <DIR>          Dataset
# 06/12/2021  01:12 p. m.                72 Untitled.ipynb
#                2 archivos      1,992,928 bytes
#                4 dirs  192,059,555,840 bytes libres

# %%
##ejemplo de sonido de perro 
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
##ejemplo de sonido de gatos
filename='Dataset/gatos.wav'
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import pandas as pd

metadata=pd.read_csv('Dataset/datos.csv')
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0     perro_ladrido
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
# 5  children_playing
# 6  children_playing
# 7  children_playing
# 8  children_playing
# 9          car_horn
